# %%
from fredapi import Fred
import pandas as pd

# ✅ Replace with your actual FRED API key
fred = Fred(api_key="aa4422c1ac7545c5837f4e5b7b52d6c8")

# 📌 List of FRED indicators to track
indicators = {
    "10Y Treasury Rate": "DGS10",
    "Fed Funds Rate": "FEDFUNDS",
    "Inflation (CPI)": "CPIAUCSL",
    "Unemployment Rate": "UNRATE",
    "High Yield Spread": "BAMLH0A0HYM2"
}

# 📈 Helper to calculate % change
def compute_change(series, period_days):
    series = series.dropna()
    if len(series) < period_days:
        return None
    start = series[-period_days]
    end = series[-1]
    return round(((end - start) / start) * 100, 2)

# 🧠 Periods (in days for daily/weekly, months for monthly)
period_map = {
    "1M Change %": 22,
    "3M Change %": 66,
    "6M Change %": 132,
    "1Y Change %": 264
}

# 🚀 Fetch & compute
all_data = []

for name, code in indicators.items():
    print(f"Fetching: {name}")
    series = fred.get_series(code)
    changes = {
        "Indicator": name,
        "Code": code
    }
    for label, period in period_map.items():
        changes[label] = compute_change(series, period)
    all_data.append(changes)

# 📤 Save to CSV
df = pd.DataFrame(all_data)
df.to_csv("fred_macro_flows.csv", index=False)
print("✅ Saved as fred_macro_flows.csv")
print(df)
# Out:
# Fetching: 10Y Treasury Rate
# <ipython-input-2-65d10e74bf86>:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start = series[-period_days]
# <ipython-input-2-65d10e74bf86>:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end = series[-1]
# Fetching: Fed Funds Rate
# Fetching: Inflation (CPI)
# Fetching: Unemployment Rate
# Fetching: High Yield Spread
# ✅ Saved as fred_macro_flows.csv
#            Indicator          Code  1M Change %  3M Change %  6M Change %  \
# 0  10Y Treasury Rate         DGS10         1.36         0.22         3.94
# 1     Fed Funds Rate      FEDFUNDS       -15.43       179.35      4711.11
# 2    Inflation (CPI)      CPIAUCSL         5.16        24.21        35.20
# 3  Unemployment Rate        UNRATE        20.00        16.67       -33.33
# 4  High Yield Spread  BAMLH0A0HYM2       -18.55        24.05        19.49
#
#    1Y Change %
# 0        -4.48
# 1       243.65
# 2        75.13
# 3       -31.15
# 4         5.18

# %%
from fredapi import Fred
import pandas as pd

# Replace with your actual FRED API key
fred = Fred(api_key="aa4422c1ac7545c5837f4e5b7b52d6c8")

# Comprehensive list of bond-related FRED series
fred_series = {
    "10Y Treasury Rate": "DGS10",
    "Fed Funds Rate": "FEDFUNDS",
    "CPI (Inflation)": "CPIAUCSL",
    "Unemployment Rate": "UNRATE",
    "High Yield Bond Spread": "BAMLH0A0HYM2",
    "Corporate Bond Yield (AAA)": "DAAA",
    "Corporate Bond Yield (BAA)": "DBAA",
    "Moody's Baa Yield Spread": "BAA10Y",
    "ICE BofA US High Yield Index Effective Yield": "BAMLH0A0HYM2EY",
    "ICE BofA BBB US Corporate Index Effective Yield": "BAMLC0A4CBBBEY",
    "Moody's Seasoned Baa Corporate Bond Yield": "BAA",
    "ICE BofA US Corporate Index Option-Adjusted Spread": "BAMLC0A0CM",
    "ICE BofA CCC & Lower US High Yield Index Effective Yield": "BAMLC0A4C3C",
    "ICE BofA BB US High Yield Index Effective Yield": "BAMLC0A4CBB",
    "ICE BofA Single-B US High Yield Index Effective Yield": "BAMLC0A4CB",
    "ICE BofA Single-A US Corporate Index Effective Yield": "BAMLC0A1CA",
    "ICE BofA AA US Corporate Index Effective Yield": "BAMLC0A2CA",
    "ICE BofA AAA US Corporate Index Effective Yield": "BAMLC0A3CA",
    "10-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB10YR",
    "5-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB5YR",
    "20-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB20YR",
    "2-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB2YR",
    "30-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB30YR",
    "12-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB12YR",
    "1-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB1YR",
    "5-Year High Quality Market (HQM) Corporate Bond Par Yield": "HQMCPY5YR",
    "15-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB15YR",
    "25-Year High Quality Market (HQM) Corporate Bond Spot Rate": "HQMCB25YR",
    "Moody's Seasoned Aaa Corporate Bond Yield": "AAA",
    "Moody's Seasoned Aaa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity": "AAA10Y",
    "Moody's Seasoned Baa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity": "BAA10Y",
    "Term Premium on a 10 Year Zero Coupon Bond": "TERMCBA",
    "Fitted Yield on a 10 Year Zero Coupon Bond": "FY10",
    "St. Louis Fed Financial Stress Index": "STLFSI",
    "10-Year Treasury Inflation-Indexed Security, Constant Maturity": "DFII10",
    "10-Year Breakeven Inflation Rate": "T10YIE",
    "5-Year Breakeven Inflation Rate": "T5YIE",
    "30-Year Treasury Constant Maturity Rate": "DGS30",
    "5-Year Treasury Constant Maturity Rate": "DGS5",
    "2-Year Treasury Constant Maturity Rate": "DGS2",
    "3-Month Treasury Constant Maturity Rate": "DGS3MO",
    "1-Month Treasury Constant Maturity Rate": "DGS1MO",
    "Effective Federal Funds Rate": "FEDFUNDS",
    "3-Month LIBOR Rate": "USD3MTD156N",
    "TED Spread": "TEDRATE",
    "3-Month Commercial Paper Minus 3-Month Treasury Bill": "CP3M",
    "10-Year Treasury Minus 3-Month Treasury Yield Spread": "T10Y3M",
    "Corporate Baa-Rated Bond Minus 10-Year Treasury": "BAA10Y",
    "High-Yield Credit Risk Spread": "BAMLH0A0HYM2EY10Y",
    "3-Month LIBOR-OIS Spread": "LIBOROIS",
    "J.P. Morgan Emerging Markets Bond Index Plus": "EMBI",
    "Chicago Board Options Exchange Market Volatility Index (VIX)": "VIXCLS",
    "Merrill Lynch Bond Market Volatility Index (1-Month)": "MLB1M",
    "S&P 500 Financials Index": "SP500FIN",
    "Net Issues of International Bonds and Notes for All Issuers": "IBANRINI3P",
    "Amounts Outstanding of International Bonds and Notes, Equity-related in Convertibles": "IBANERCAO",
    "Amount Outstanding of Domestic Bonds and Notes in Non-Financial Corporations Sector, Long-Term at Original Maturity, Canada": "DBNLTRIAONCCA",
    "Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Sweden": "DDAM03SEA156NWDB",
    "Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Italy": "DDAM03ITA156NWDB",
    "Amounts Outstanding of International Bonds and Notes, Fixed Rate in Currency of Issue in US dollar": "IBANFXUSAO",
    "Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Poland": "DDAM03PLA156NWDB",
    "Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Peru": "DDAM03PEA156NWDB"
}

# Helper function to calculate percentage change
def compute_change(series, months):
    series = series.dropna()
    if len(series) < months:
        return None
    start = series.iloc[-months]
    end = series.iloc[-1]
    return round(((end - start) / start) * 100, 2)

# Retrieve and compute data
results = []

for name, code in fred_series.items():
    print(f"Fetching data for: {name}")
    try:
        series = fred.get_series(code, frequency='m')  # monthly frequency
        row = {
            "Indicator": name,
            "Code": code,
            "1M Change %": compute_change(series, 1),
            "3M Change %": compute_change(series, 3),
            "6M Change %": compute_change(series, 6),
            "1Y Change %": compute_change(series, 12),
            "5Y Change %": compute_change(series, 60)
        }
        results.append(row)
    except Exception as e:
        print(f"Error fetching data for {name}: {e}")

# Save results to CSV
df = pd.DataFrame(results)
df.to_csv("fred_bond_indicators.csv", index=False)
print("Data saved to fred_bond_indicators.csv")
print(df)
# Out:
# Fetching data for: 10Y Treasury Rate
# Fetching data for: Fed Funds Rate
# Fetching data for: CPI (Inflation)
# Fetching data for: Unemployment Rate
# Fetching data for: High Yield Bond Spread
# Fetching data for: Corporate Bond Yield (AAA)
# Fetching data for: Corporate Bond Yield (BAA)
# Fetching data for: Moody's Baa Yield Spread
# Fetching data for: ICE BofA US High Yield Index Effective Yield
# Fetching data for: ICE BofA BBB US Corporate Index Effective Yield
# Fetching data for: Moody's Seasoned Baa Corporate Bond Yield
# Fetching data for: ICE BofA US Corporate Index Option-Adjusted Spread
# Fetching data for: ICE BofA CCC & Lower US High Yield Index Effective Yield
# Error fetching data for ICE BofA CCC & Lower US High Yield Index Effective Yield: Bad Request.  The series does not exist.
# Fetching data for: ICE BofA BB US High Yield Index Effective Yield
# Error fetching data for ICE BofA BB US High Yield Index Effective Yield: Bad Request.  The series does not exist.
# Fetching data for: ICE BofA Single-B US High Yield Index Effective Yield
# Error fetching data for ICE BofA Single-B US High Yield Index Effective Yield: Bad Request.  The series does not exist.
# Fetching data for: ICE BofA Single-A US Corporate Index Effective Yield
# Error fetching data for ICE BofA Single-A US Corporate Index Effective Yield: Bad Request.  The series does not exist.
# Fetching data for: ICE BofA AA US Corporate Index Effective Yield
# Error fetching data for ICE BofA AA US Corporate Index Effective Yield: Bad Request.  The series does not exist.
# Fetching data for: ICE BofA AAA US Corporate Index Effective Yield
# Fetching data for: 10-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 5-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 20-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 2-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 30-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 12-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 1-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 5-Year High Quality Market (HQM) Corporate Bond Par Yield
# Error fetching data for 5-Year High Quality Market (HQM) Corporate Bond Par Yield: Bad Request.  The series does not exist.
# Fetching data for: 15-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: 25-Year High Quality Market (HQM) Corporate Bond Spot Rate
# Fetching data for: Moody's Seasoned Aaa Corporate Bond Yield
# Fetching data for: Moody's Seasoned Aaa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity
# Fetching data for: Moody's Seasoned Baa Corporate Bond Yield Relative to Yield on 10-Year Treasury Constant Maturity
# Fetching data for: Term Premium on a 10 Year Zero Coupon Bond
# Error fetching data for Term Premium on a 10 Year Zero Coupon Bond: Bad Request.  The series does not exist.
# Fetching data for: Fitted Yield on a 10 Year Zero Coupon Bond
# Error fetching data for Fitted Yield on a 10 Year Zero Coupon Bond: Bad Request.  The series does not exist.
# Fetching data for: St. Louis Fed Financial Stress Index
# Fetching data for: 10-Year Treasury Inflation-Indexed Security, Constant Maturity
# Fetching data for: 10-Year Breakeven Inflation Rate
# Fetching data for: 5-Year Breakeven Inflation Rate
# Fetching data for: 30-Year Treasury Constant Maturity Rate
# Fetching data for: 5-Year Treasury Constant Maturity Rate
# Fetching data for: 2-Year Treasury Constant Maturity Rate
# Fetching data for: 3-Month Treasury Constant Maturity Rate
# Fetching data for: 1-Month Treasury Constant Maturity Rate
# Fetching data for: Effective Federal Funds Rate
# Fetching data for: 3-Month LIBOR Rate
# Error fetching data for 3-Month LIBOR Rate: Bad Request.  The series does not exist.
# Fetching data for: TED Spread
# Fetching data for: 3-Month Commercial Paper Minus 3-Month Treasury Bill
# Fetching data for: 10-Year Treasury Minus 3-Month Treasury Yield Spread
# Fetching data for: Corporate Baa-Rated Bond Minus 10-Year Treasury
# Fetching data for: High-Yield Credit Risk Spread
# Error fetching data for High-Yield Credit Risk Spread: Bad Request.  The series does not exist.
# Fetching data for: 3-Month LIBOR-OIS Spread
# Error fetching data for 3-Month LIBOR-OIS Spread: Bad Request.  The series does not exist.
# Fetching data for: J.P. Morgan Emerging Markets Bond Index Plus
# Error fetching data for J.P. Morgan Emerging Markets Bond Index Plus: Bad Request.  The series does not exist.
# Fetching data for: Chicago Board Options Exchange Market Volatility Index (VIX)
# Fetching data for: Merrill Lynch Bond Market Volatility Index (1-Month)
# Error fetching data for Merrill Lynch Bond Market Volatility Index (1-Month): Bad Request.  The series does not exist.
# Fetching data for: S&P 500 Financials Index
# Error fetching data for S&P 500 Financials Index: Bad Request.  The series does not exist.
# Fetching data for: Net Issues of International Bonds and Notes for All Issuers
# Error fetching data for Net Issues of International Bonds and Notes for All Issuers: Bad Request.  Value of frequency is not one of: 'q', 'sa', 'a'.
# Fetching data for: Amounts Outstanding of International Bonds and Notes, Equity-related in Convertibles
# Error fetching data for Amounts Outstanding of International Bonds and Notes, Equity-related in Convertibles: Bad Request.  Value of frequency is not one of: 'q', 'sa', 'a'.
# Fetching data for: Amount Outstanding of Domestic Bonds and Notes in Non-Financial Corporations Sector, Long-Term at Original Maturity, Canada
# Error fetching data for Amount Outstanding of Domestic Bonds and Notes in Non-Financial Corporations Sector, Long-Term at Original Maturity, Canada: Bad Request.  Value of frequency is not one of: 'q', 'sa', 'a'.
# Fetching data for: Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Sweden
# Error fetching data for Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Sweden: Bad Request.  Value of frequency is not one of: 'a'.
# Fetching data for: Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Italy
# Error fetching data for Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Italy: Bad Request.  Value of frequency is not one of: 'a'.
# Fetching data for: Amounts Outstanding of International Bonds and Notes, Fixed Rate in Currency of Issue in US dollar
# Error fetching data for Amounts Outstanding of International Bonds and Notes, Fixed Rate in Currency of Issue in US dollar: Bad Request.  Value of frequency is not one of: 'q', 'sa', 'a'.
# Fetching data for: Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Poland
# Error fetching data for Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Poland: Bad Request.  Value of frequency is not one of: 'a'.
# Fetching data for: Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Peru
# Error fetching data for Nonfinancial Corporate Bonds to Total Bonds and Notes Outstanding for Peru: Bad Request.  Value of frequency is not one of: 'a'.
# Data saved to fred_bond_indicators.csv
#                                             Indicator            Code  \
# 0                                   10Y Treasury Rate           DGS10
# 1                                      Fed Funds Rate        FEDFUNDS
# 2                                     CPI (Inflation)        CPIAUCSL
# 3                                   Unemployment Rate          UNRATE
# 4                              High Yield Bond Spread    BAMLH0A0HYM2
# 5                          Corporate Bond Yield (AAA)            DAAA
# 6                          Corporate Bond Yield (BAA)            DBAA
# 7                            Moody's Baa Yield Spread          BAA10Y
# 8        ICE BofA US High Yield Index Effective Yield  BAMLH0A0HYM2EY
# 9     ICE BofA BBB US Corporate Index Effective Yield  BAMLC0A4CBBBEY
# 10          Moody's Seasoned Baa Corporate Bond Yield             BAA
# 11  ICE BofA US Corporate Index Option-Adjusted Sp...      BAMLC0A0CM
# 12    ICE BofA AAA US Corporate Index Effective Yield      BAMLC0A3CA
# 13  10-Year High Quality Market (HQM) Corporate Bo...       HQMCB10YR
# 14  5-Year High Quality Market (HQM) Corporate Bon...        HQMCB5YR
# 15  20-Year High Quality Market (HQM) Corporate Bo...       HQMCB20YR
# 16  2-Year High Quality Market (HQM) Corporate Bon...        HQMCB2YR
# 17  30-Year High Quality Market (HQM) Corporate Bo...       HQMCB30YR
# 18  12-Year High Quality Market (HQM) Corporate Bo...       HQMCB12YR
# 19  1-Year High Quality Market (HQM) Corporate Bon...        HQMCB1YR
# 20  15-Year High Quality Market (HQM) Corporate Bo...       HQMCB15YR
# 21  25-Year High Quality Market (HQM) Corporate Bo...       HQMCB25YR
# 22          Moody's Seasoned Aaa Corporate Bond Yield             AAA
# 23  Moody's Seasoned Aaa Corporate Bond Yield Rela...          AAA10Y
# 24  Moody's Seasoned Baa Corporate Bond Yield Rela...          BAA10Y
# 25               St. Louis Fed Financial Stress Index          STLFSI
# 26  10-Year Treasury Inflation-Indexed Security, C...          DFII10
# 27                   10-Year Breakeven Inflation Rate          T10YIE
# 28                    5-Year Breakeven Inflation Rate           T5YIE
# 29            30-Year Treasury Constant Maturity Rate           DGS30
# 30             5-Year Treasury Constant Maturity Rate            DGS5
# 31             2-Year Treasury Constant Maturity Rate            DGS2
# 32            3-Month Treasury Constant Maturity Rate          DGS3MO
# 33            1-Month Treasury Constant Maturity Rate          DGS1MO
# 34                       Effective Federal Funds Rate        FEDFUNDS
# 35                                         TED Spread         TEDRATE
# 36  3-Month Commercial Paper Minus 3-Month Treasur...            CP3M
# 37  10-Year Treasury Minus 3-Month Treasury Yield ...          T10Y3M
# 38    Corporate Baa-Rated Bond Minus 10-Year Treasury          BAA10Y
# 39  Chicago Board Options Exchange Market Volatili...          VIXCLS
#
#     1M Change %  3M Change %  6M Change %  1Y Change %  5Y Change %
# 0           0.0        -3.82        -1.83        -4.46       538.81
# 1           0.0         0.00        -6.68       -18.76      8560.00
# 2           0.0         0.17         1.22         2.29        25.22
# 3           0.0         2.44         0.00         5.00       -68.18
# 4           0.0        48.71        49.26        29.17       -44.72
# 5           0.0         2.44         6.03         3.81       118.00
# 6           0.0         4.39         6.92         3.87        56.46
# 7           0.0        29.25        33.80        29.25       -42.07
# 8           0.0        14.20        14.20         3.24         3.51
# 9           0.0         2.21         3.54        -3.30        67.47
# 10          0.0         4.39         6.92         3.87        56.46
# 11          0.0        35.37        37.04        24.72       -46.63
# 12          0.0        34.78        38.81        24.00       -41.14
# 13          0.0         0.95         3.50         0.00       105.00
# 14          0.0        -2.29        -0.84        -6.37       228.67
# 15          0.0         4.59         7.43         5.70        77.54
# 16          0.0        -3.92        -4.55       -15.19       336.63
# 17          0.0         3.81         8.51         6.96        74.64
# 18          0.0         1.66         4.55         1.29        88.70
# 19          0.0        -1.55        -4.09       -17.71       457.50
# 20          0.0         3.24         5.91         3.24        79.62
# 21          0.0         4.19         7.96         6.61        76.11
# 22          0.0         2.44         6.03         3.81       118.00
# 23          0.0        34.48        50.00        51.95       -36.07
# 24          0.0        29.25        33.80        29.25       -42.07
# 25         -0.0         8.25        15.68        23.79        33.48
# 26          0.0         0.49         0.49        -5.12      -563.64
# 27          0.0        -7.44        -3.45        -3.86       100.00
# 28          0.0        -9.96        -1.67         0.86       205.19
# 29          0.0         0.64         3.74         1.95       241.30
# 30          0.0        -8.64        -7.57       -13.11      1050.00
# 31          0.0       -10.21       -11.27       -22.22      2123.53
# 32          0.0        -0.23        -6.49       -20.88      3223.08
# 33          0.0        -0.46        -7.64       -20.91      4250.00
# 34          0.0         0.00        -6.68       -18.76      8560.00
# 35          0.0       100.00        75.00         0.00       -72.55
# 36          0.0        -1.59         0.00         0.72        71.60
# 37         -0.0      -133.33       -84.62       -95.88      -107.27
# 38          0.0        29.25        33.80        29.25       -42.07
# 39          0.0        88.39        99.56       144.79         3.46

# %%
pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.5.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fredapi) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fredapi) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.17.0)
# Downloading fredapi-0.5.2-py3-none-any.whl (11 kB)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.2
